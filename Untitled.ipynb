# %%
from PIL import Image
import numpy as np

# %%
icon = Image.open('icon.jpg')

# %%
icon
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F27502226A0>

# %%
icon_np = np.asarray(icon)

# %%
Image.fromarray(icon_np[:, ::-1, :])
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F274DC43080>

# %%
icon_rotate = Image.fromarray(icon_np[:,10:,:])

# %%
icon_rotate.rotate(10)
# Out:
# <PIL.Image.Image image mode=RGB size=490x500 at 0x7F274DC3EDD8>

# %%
# baseline
np.mean([0.6948017307806296,
0.6987005486572335,
0.7002980967667966,
0.6978502510861592,
0.6974440712699949])
# Out:
# 0.6978189397121628

# %%
# dropout
np.mean([0.7027453633237499,
0.7004501904651967,
0.7039413382218149,
0.7030868057529419,
0.70295524908528])
# Out:
# 0.7026357893697968

# %%
# word dropout
np.mean([0.6955124526569494,
0.6978160313835705,
0.6959024720623096,
0.695230578419213,
0.6969426068299659])
# Out:
# 0.6962808282704016

# %%
# semantic dropout
np.mean([0.7003850192509626,
0.7033704097032027,
0.7019921241602965,
0.7049675023212627,
0.7014357868452414])
# Out:
# 0.7024301684561932

# %%
# Gaussian Noise 0.1
np.mean([0.6895503615973168,
         0.6950278611230176,
         0.6978537315150469,
         0.7000675523530736,
         0.6980427145485976])
# Out:
# 0.6961084442274106

# %%
# Gaussian Noise 0.01
np.mean([0.6973573942678362,
        0.6999382473474429,
        0.6960919034793602,
        0.6946277611126261,
        0.6929751837727298])
# Out:
# 0.6961980979959991

# %%
# Adversarial Noise 0.01
np.mean([0.6880865277556862,
0.695686230627203,
0.6943375174337517,
0.6976245556621341,
0.6939148304600982,])
# Out:
# 0.6939299323877748

# %%
# Adversarial Noise 0.1
np.mean([0.6901546504029624,
        0.6891524317266893,
        0.6849723032938233,
        0.6727610948711136,
        0.6852761729928191])
# Out:
# 0.6844633306574817
